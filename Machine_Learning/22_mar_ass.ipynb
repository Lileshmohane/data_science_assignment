# %% [markdown]
# Q1. Pearson correlation coefficient is a measure of the linear relationship between two variables. Suppose
# you have collected data on the amount of time students spend studying for an exam and their final exam
# scores. Calculate the Pearson correlation coefficient between these two variables and interpret the result.

# %% [markdown]
# r = ∑ (Xi−Xˉ)(Yi− Yˉ)/√∑(Xi−Xˉ)2(Yi− Yˉ)2

# %% [markdown]
# Here,
# Xi and Yi
#   are the individual data points, ˉX and  ˉY are the means of the two variables, and the summation is over all data points

# %% [markdown]
# Let's assume you have the following data:
#
# Time Spent (hours):
# [
# 10
# ,
# 8
# ,
# 12
# ,
# 15
# ,
# 7
# ]
# Exam Scores:
# [
# 85
# ,
# 75
# ,
# 90
# ,
# 92
# ,
# 70
# ]
# Time Spent (hours):
# Exam Scores:
# ​
#
# [10,8,12,15,7]
# [85,75,90,92,70]
# ​

# %% [markdown]
# Calculate the mean for both time spent and exam scores:
# ˉX=
# 10
# +
# 8
# +
# 12
# +
# 15
# +
# 7
# 5
# =
# 52
# 5
# =
# 10.4
# y
# ˉ
# =
# 85
# +
# 75
# +
# 90
# +
# 92
# +
# 70
# 5
# =
# 412
# 5
# =
# 82.4

# %% [markdown]
# Substitute these values into the Pearson correlation coefficient formula:

# %% [markdown]
# After calculating this, you will get a numerical value for
# r, which will be between -1 and 1. The sign indicates the direction of the correlation (positive for a positive correlation, negative for a negative correlation), and the magnitude indicates the strength of the correlation.
#
# Interpretation:
#
# If
# r is close to 1, it indicates a strong positive linear relationship. This means that as the time spent studying increases, the exam scores also tend to increase.
# If
# r is close to -1, it indicates a strong negative linear relationship. This means that as the time spent studying increases, the exam scores tend to decrease.
# If
# r is close to 0, it indicates a weak or no linear relationship between the two variables.

# %% [markdown]
# Q2. Spearman's rank correlation is a measure of the monotonic relationship between two variables.
# Suppose you have collected data on the amount of sleep individuals get each night and their overall job
# satisfaction level on a scale of 1 to 10. Calculate the Spearman's rank correlation between these two
# variables and interpret the result.

# %% [markdown]
# Spearman's rank correlation is a non-parametric measure of the strength and direction of monotonic relationships between two variables. It is based on the ranks of the data rather than the actual values. Here's how you can calculate Spearman's rank correlation:
#
# Rank the data for both variables separately.
# Compute the differences between the ranks for each pair of data points.
# Square each of these differences.
# Sum up these squared differences.
# Use the formula for Spearman's rank correlation:
# ρ=1−  6∑d2/n(n2−1)
#
#
# ρ is the Spearman's rank correlation coefficient.
# di
#  is the difference between the ranks of corresponding data points.
#
# n is the number of data points.
# Let's assume you have the following data:
#
#
# Sleep (hours):
# Job Satisfaction
#
# [7,6,8,5,7]
# [8,5,9,4,7]
#
# Rank the data:
#
# Sleep (hours):
# Job Satisfaction:
#
# [3,4,2,5,3]
# [2,4,1,5,3]
#
# Compute the differences:
#
# di
#
# [1,0,−1,0,0]
#
# Square each difference:
#
# d2
# [1,0,1,0,0]
#
#
# Sum up the squared differences:
#
# ∑d2 =2
#
# After calculating this, you will get a numerical value for
#
# ρ, which will be between -1 and 1. The interpretation is similar to Pearson correlation:

# %% [markdown]
# Q3. Suppose you are conducting a study to examine the relationship between the number of hours of
# exercise per week and body mass index (BMI) in a sample of adults. You collected data on both variables
# for 50 participants. Calculate the Pearson correlation coefficient and the Spearman's rank correlation
# between these two variables and compare the results.

# %% [markdown]
# To calculate the Pearson correlation coefficient and the Spearman's rank correlation between the number of hours of exercise per week and body mass index (BMI), you'll follow similar steps as mentioned in the previous examples. Let's denote the number of hours of exercise as
#
# X and BMI as
#
# Y for each participant.
#
# Assume you have the following data:
#
#
#
# (50 values)
# Number of Hours of Exercise (X):
# BMI (Y):
#
# [3,5,2,4,6,…](50 values)
# [25.5,28.0,23.3,26.1,29.5,…](50 values)
#
# Calculate Pearson Correlation Coefficient (
# r):
# Calculate Spearman's Rank Correlation (
# ρ):
# Rank the data for both
# X and
# Y variables. Let
# R
# X
#  and
# R
# Y  be the ranks.
#
# Calculate the differences
# di=RX−RY
#
#   for each data point.
#
# Compute
# ρ using the formula:

# %% [markdown]
# Q4. A researcher is interested in examining the relationship between the number of hours individuals
# spend watching television per day and their level of physical activity. The researcher collected data on
# both variables from a sample of 50 participants. Calculate the Pearson correlation coefficient between
# these two variables.

# %% [markdown]
# To calculate the Pearson correlation coefficient (
# r) between the number of hours individuals spend watching television per day and their level of physical activity, you can use the following formula:
#     r = ∑ (Xi−Xˉ)(Yi− Yˉ)/√∑(Xi−Xˉ)2(Yi− Yˉ)2
#
# Here, Xi represents the number of hours spent watching television for each individual,
# and yi represents their level of physical activity
# xˉ  Yˉ are the means of the two variables.
# Assuming you have the following data:
# Hours of TV (X):
# Physical Activity (Y):
#
# [2,3,1,4,2,…](50 values)
# [5,4,6,3,5,…](50 values)
#
# Calculate the means:
#     Substitute the values into the formula and compute
#
# r. The result will be a number between -1 and 1:
#
# If
#
# r is close to 1, it indicates a strong positive linear relationship. This would mean that as the number of hours of TV watching increases, the level of physical activity tends to increase.
# If
#
# r is close to -1, it indicates a strong negative linear relationship. This would mean that as the number of hours of TV watching increases, the level of physical activity tends to decrease.
# If
#
# r is close to 0, it suggests a weak or no linear relationship between the two variables.

# %% [markdown]
# Q5. A survey was conducted to examine the relationship between age and preference for a particular
# brand of soft drink. The survey results are shown below:
# Age(Years)
# 25
# 42
# 37
# 19
# 31
# 28
# Soft drink Preference
# Coke
# Pepsi
# Mountain dew
# Coke
# Pepsi
# Coke

# %% [markdown]
# To examine the relationship between age and preference for a particular brand of soft drink, you can use various statistical measures. In this case, you can calculate the point-biserial correlation coefficient because one variable (age) is continuous, and the other variable (soft drink preference) is binary.
#
# Here are the steps to calculate the point-biserial correlation coefficient:
#
# Assign numerical values to the soft drink preference variable. For example, you can use 0 for Coke, and 1 for Pepsi or Mountain Dew.
# Calculate the mean of the age variable (
# Xˉ
#  ) and the mean of the binary variable.
# Xˉ
#   (mean age) =
# 25+42+37+19+31+28
# Mean of binary variable (mean preference) =
#
# 0+1+2+0+1+0/6
# Interpret the result:

# %% [markdown]
# Q6. A company is interested in examining the relationship between the number of sales calls made per day
# and the number of sales made per week. The company collected data on both variables from a sample of
# 30 sales representatives. Calculate the Pearson correlation coefficient between these two variables.

# %%
To calculate the Pearson correlation coefficient (
r) between the number of sales calls made per day and the number of sales made per week, you can use the following formula:
    r = ∑ (Xi−Xˉ)(Yi− Yˉ)/√∑(Xi−Xˉ)2(Yi− Yˉ)2
    Sales Calls per Day (X):
Sales per Week (Y):
[20,15,25,18,22,…](30 values)
[3,2,4,3,4,…](30 values)
If 

r is close to 1, it indicates a strong positive linear relationship. This would mean that as the number of sales calls per day increases, the number of sales per week tends to increase.
If 

r is close to -1, it indicates a strong negative linear relationship. This would mean that as the number of sales calls per day increases, the number of sales per week tends to decrease.
If 

r is close to 0, it suggests a weak or no linear relationship between the two variables.
